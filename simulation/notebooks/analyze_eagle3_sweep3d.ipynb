# %% [markdown]
# # EAGLE3 Per-Step Latency Decomposition
#
# Analyzes per-step cost decomposed into `target_forward_ms`, `eagle3_draft_ms`,
# `verify_overhead_ms`, `post_verify_ms`.
#
# Accepts either schema:
#
# 1. **New (per-workload)** — `simulation/scripts/measure_eagle3_cost.py` output.
#    Rows are keyed by `(workload, topk, steps, budget)`; this notebook
#    medians across workloads so each `(topk, steps, budget)` has one row.
#    Some legacy fields (`verify_overhead_ms`, `step_total_ms`) are derived
#    from `target_cost_ms - target_forward_ms` and `step_ms` respectively.
# 2. **Legacy (flat)** — `scripts/sweep_eagle3_latency.py` output with one
#    row per `(topk, steps, budget)` and all decomposition fields present.
#
# `BENCH_PATH` below is auto-picked from known locations; override manually
# if needed.

# %%
import json
from pathlib import Path

import matplotlib
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

matplotlib.rcParams.update({
    'font.size': 11,
    'figure.figsize': (12, 5),
    'figure.dpi': 100,
})

# %%
# Candidate paths — first existing wins. New per-workload output takes
# precedence over the legacy flat output.
_CANDIDATES = [
    "/home/muchwater/advance-spec/simulation/results/latency/qwen3_14b/eagle3_cost.json",
    "/home/muchwater/advance-spec/simulation/results/latency/qwen3_8b/eagle3_cost.json",
    "/home/muchwater/advance-spec/results/qwen3_14b/eagle3_sweep3d.json",
    "/home/muchwater/advance-spec/results/qwen3_8b/eagle3_sweep3d.json",
]
BENCH_PATH = next((p for p in _CANDIDATES if Path(p).exists()), _CANDIDATES[0])

with open(BENCH_PATH) as f:
    data = json.load(f)

raw_df = pd.DataFrame(data['results'])

# Stamp per-row topk when only file-level topk is present (legacy single-topk).
if 'topk' not in raw_df.columns and 'topk' in data:
    raw_df['topk'] = data['topk']

# Split ok / err rows
err_mask = raw_df['error'].notna() if 'error' in raw_df.columns else \
    pd.Series([False] * len(raw_df))
ok_raw = raw_df[~err_mask].reset_index(drop=True)
err_raw = raw_df[err_mask].reset_index(drop=True)

# If per-workload schema, median across workloads per (topk, steps, budget).
if 'workload' in ok_raw.columns:
    grp_keys = ['topk', 'steps', 'budget']
    num_cols = [c for c in ok_raw.columns
                if c not in grp_keys + ['workload', 'error']
                and pd.api.types.is_numeric_dtype(ok_raw[c])]
    ok = ok_raw.groupby(grp_keys, as_index=False)[num_cols].median()
    # err: dedupe on (topk, steps, budget), keep first.
    err = (err_raw.drop_duplicates(['topk', 'steps', 'budget'])
           .reset_index(drop=True)
           if len(err_raw) else err_raw)
else:
    ok = ok_raw
    err = err_raw

# --- Fill in legacy decomposition fields when the new script omits them ---
# measure_eagle3_cost.py reports `target_cost_ms` (= median verify_total_ms),
# `target_forward_ms`, `draft_cost_ms`, `step_ms` and nothing else. Old
# sweep_eagle3_latency.py reported the full breakdown. Backfill so the
# downstream plots still render (missing components show as zero, not NaN).
if 'target_cost_ms' in ok.columns:
    ok = ok.rename(columns={'draft_cost_ms': 'eagle3_draft_ms'}) \
        if 'draft_cost_ms' in ok.columns and 'eagle3_draft_ms' not in ok.columns \
        else ok
    if 'verify_total_ms' not in ok.columns:
        ok['verify_total_ms'] = ok['target_cost_ms']
    if 'verify_overhead_ms' not in ok.columns:
        ok['verify_overhead_ms'] = (ok['target_cost_ms']
                                    - ok['target_forward_ms']).clip(lower=0)
    if 'step_total_ms' not in ok.columns:
        ok['step_total_ms'] = ok.get('step_ms', ok['target_cost_ms']
                                     + ok.get('eagle3_draft_ms', 0))
    for col in ('post_verify_ms', 'verify_greedy_ms'):
        if col not in ok.columns:
            ok[col] = 0.0

# Vanilla TPOT: legacy had it top-level. New schema doesn't — proxy by
# target_forward_ms at the smallest measured budget.
vanilla_tpot = data.get('vanilla_tpot_ms')
if vanilla_tpot is None and len(ok):
    b_min_idx = ok['budget'].idxmin()
    vanilla_tpot = float(ok.loc[b_min_idx, 'target_forward_ms'])

# Re-export `all_df` for any cell that still references it.
all_df = raw_df

print(f"Bench:  {BENCH_PATH}")
print(f"Model:  {data.get('model')}")
print(f"Draft:  {data.get('draft_model')}")
print(f"Vanilla TPOT: {vanilla_tpot:.2f} ms/tok "
      f"({'provided' if data.get('vanilla_tpot_ms') is not None else 'proxy from B_min'})")
print(f"OK rows: {len(ok)}  ({len(ok_raw)} pre-aggregation)  "
      f"Err: {len(err)}")
# In latency-only (real speculative) mode:
#   step_total_ms = one speculative step (draft+verify) wall time
#   step_ms       = effective per-token TPOT (total wall / committed tokens)
# Out:
# Model: Qwen/Qwen3-14B
# Draft: AngelSlim/Qwen3-14B_eagle3
# Vanilla TPOT: 25.32 ms/tok
# Configs: 289 total, 243 ok, 46 errored
# Grid: topks=[np.int64(1), np.int64(2), np.int64(4), np.int64(8), np.int64(16)], steps=[np.int64(1), np.int64(2), np.int64(3), np.int64(4), np.int64(5), np.int64(6), np.int64(7), np.int64(8)], budgets=[np.int64(1), np.int64(2), np.int64(4), np.int64(8), np.int64(16), np.int64(32), np.int64(64), np.int64(128), np.int64(256), np.int64(512), np.int64(1024)]
# accept_length_mean range: 0.00 – 2.28

# %% [markdown]
# ## Summary table
#
# All successful configs with their decomposition. `overhead_ms = step_ms - target_forward_ms - eagle3_draft_ms` captures verify + post_verify + misc.

# %%
# step_total_ms = per-step wall time (true step latency).
# step_ms (TPOT) is effective per-token time in real spec mode — kept for reference.
view_cols = ['topk', 'steps', 'budget', 'step_total_ms', 'step_ms', 'target_forward_ms',
             'eagle3_draft_ms', 'verify_overhead_ms', 'post_verify_ms',
             'verify_greedy_ms', 'n_samples']
summary = ok[view_cols].sort_values('step_total_ms').reset_index(drop=True)
summary.style.background_gradient(subset=['step_total_ms'], cmap='RdYlGn_r') \
             .background_gradient(subset=['verify_overhead_ms'], cmap='Reds') \
             .format({c: '{:.2f}' for c in view_cols if c.endswith('_ms')})
# Out:
# <style type="text/css">
# #T_b80b4_row0_col3, #T_b80b4_row1_col3, #T_b80b4_row2_col3, #T_b80b4_row3_col3 {
#   background-color: #006837;
#   color: #f1f1f1;
# }
# #T_b80b4_row0_col7, #T_b80b4_row1_col7, #T_b80b4_row2_col7, #T_b80b4_row3_col7, #T_b80b4_row4_col7, #T_b80b4_row6_col7, #T_b80b4_row7_col7, #T_b80b4_row8_col7, #T_b80b4_row14_col7, #T_b80b4_row15_col7, #T_b80b4_row16_col7, #T_b80b4_row17_col7, #T_b80b4_row21_col7, #T_b80b4_row32_col7, #T_b80b4_row33_col7, #T_b80b4_row34_col7, #T_b80b4_row35_col7, #T_b80b4_row42_col7, #T_b80b4_row44_col7, #T_b80b4_row50_col7, #T_b80b4_row52_col7, #T_b80b4_row53_col7, #T_b80b4_row54_col7, #T_b80b4_row56_col7, #T_b80b4_row70_col7, #T_b80b4_row71_col7, #T_b80b4_row73_col7, #T_b80b4_row74_col7, #T_b80b4_row77_col7, #T_b80b4_row78_col7, #T_b80b4_row85_col7, #T_b80b4_row86_col7, #T_b80b4_row87_col7, #T_b80b4_row90_col7, #T_b80b4_row94_col7, #T_b80b4_row95_col7, #T_b80b4_row98_col7, #T_b80b4_row100_col7, #T_b80b4_row105_col7, #T_b80b4_row108_col7, #T_b80b4_row110_col7, #T_b80b4_row112_col7, #T_b80b4_row113_col7, #T_b80b4_row115_col7, #T_b80b4_row116_col7, #T_b80b4_row117_col7, #T_b80b4_row121_col7, #T_b80b4_row123_col7, #T_b80b4_row133_col7, #T_b80b4_row134_col7, #T_b80b4_row136_col7, #T_b80b4_row139_col7, #T_b80b4_row141_col7, #T_b80b4_row143_col7, #T_b80b4_row145_col7, #T_b80b4_row146_col7, #T_b80b4_row155_col7, #T_b80b4_row160_col7, #T_b80b4_row162_col7, #T_b80b4_row163_col7, #T_b80b4_row169_col7 {
#   background-color: #fff5f0;
#   color: #000000;
# }
# #T_b80b4_row4_col3, #T_b80b4_row5_col3, #T_b80b4_row6_col3, #T_b80b4_row7_col3, #T_b80b4_row8_col3, #T_b80b4_row9_col3, #T_b80b4_row10_col3, #T_b80b4_row11_col3, #T_b80b4_row12_col3, #T_b80b4_row13_col3, #T_b80b4_row14_col3, #T_b80b4_row15_col3, #T_b80b4_row16_col3 {
#   background-color: #016a38;
#   color: #f1f1f1;
# }
# #T_b80b4_row5_col7, #T_b80b4_row9_col7, #T_b80b4_row10_col7, #T_b80b4_row11_col7, #T_b80b4_row12_col7, #T_b80b4_row13_col7, #T_b80b4_row19_col7, #T_b80b4_row20_col7, #T_b80b4_row22_col7, #T_b80b4_row23_col7, #T_b80b4_row24_col7, #T_b80b4_row25_col7, #T_b80b4_row26_col7, #T_b80b4_row27_col7, #T_b80b4_row28_col7, #T_b80b4_row29_col7, #T_b80b4_row30_col7, #T_b80b4_row31_col7, #T_b80b4_row37_col7, #T_b80b4_row39_col7, #T_b80b4_row40_col7, #T_b80b4_row41_col7, #T_b80b4_row43_col7, #T_b80b4_row45_col7, #T_b80b4_row46_col7, #T_b80b4_row47_col7, #T_b80b4_row48_col7, #T_b80b4_row49_col7, #T_b80b4_row51_col7, #T_b80b4_row55_col7, #T_b80b4_row60_col7, #T_b80b4_row61_col7, #T_b80b4_row62_col7, #T_b80b4_row63_col7, #T_b80b4_row64_col7, #T_b80b4_row65_col7, #T_b80b4_row66_col7, #T_b80b4_row67_col7, #T_b80b4_row68_col7, #T_b80b4_row69_col7, #T_b80b4_row72_col7, #T_b80b4_row75_col7, #T_b80b4_row76_col7, #T_b80b4_row81_col7, #T_b80b4_row82_col7, #T_b80b4_row83_col7, #T_b80b4_row88_col7, #T_b80b4_row89_col7, #T_b80b4_row91_col7, #T_b80b4_row92_col7, #T_b80b4_row93_col7, #T_b80b4_row96_col7, #T_b80b4_row97_col7, #T_b80b4_row99_col7, #T_b80b4_row102_col7, #T_b80b4_row104_col7, #T_b80b4_row109_col7, #T_b80b4_row111_col7, #T_b80b4_row114_col7, #T_b80b4_row118_col7, #T_b80b4_row119_col7, #T_b80b4_row120_col7, #T_b80b4_row122_col7, #T_b80b4_row124_col7, #T_b80b4_row126_col7, #T_b80b4_row127_col7, #T_b80b4_row135_col7, #T_b80b4_row137_col7, #T_b80b4_row138_col7, #T_b80b4_row140_col7, #T_b80b4_row142_col7, #T_b80b4_row144_col7, #T_b80b4_row147_col7, #T_b80b4_row148_col7, #T_b80b4_row149_col7, #T_b80b4_row151_col7, #T_b80b4_row152_col7, #T_b80b4_row161_col7, #T_b80b4_row164_col7, #T_b80b4_row165_col7, #T_b80b4_row166_col7, #T_b80b4_row167_col7, #T_b80b4_row168_col7, #T_b80b4_row170_col7, #T_b80b4_row171_col7 {
#   background-color: #fff4ef;
#   color: #000000;
# }
# #T_b80b4_row17_col3, #T_b80b4_row18_col3 {
#   background-color: #026c39;
#   color: #f1f1f1;
# }
# #T_b80b4_row18_col7, #T_b80b4_row36_col7, #T_b80b4_row38_col7, #T_b80b4_row57_col7, #T_b80b4_row58_col7, #T_b80b4_row59_col7, #T_b80b4_row79_col7, #T_b80b4_row80_col7, #T_b80b4_row84_col7, #T_b80b4_row101_col7, #T_b80b4_row103_col7, #T_b80b4_row106_col7, #T_b80b4_row107_col7, #T_b80b4_row125_col7, #T_b80b4_row129_col7, #T_b80b4_row131_col7, #T_b80b4_row132_col7, #T_b80b4_row150_col7, #T_b80b4_row156_col7, #T_b80b4_row158_col7, #T_b80b4_row159_col7, #T_b80b4_row173_col7, #T_b80b4_row175_col7, #T_b80b4_row177_col7, #T_b80b4_row178_col7 {
#   background-color: #fff4ee;
#   color: #000000;
# }
# #T_b80b4_row19_col3, #T_b80b4_row20_col3, #T_b80b4_row21_col3, #T_b80b4_row22_col3, #T_b80b4_row23_col3, #T_b80b4_row24_col3, #T_b80b4_row25_col3, #T_b80b4_row26_col3, #T_b80b4_row27_col3, #T_b80b4_row28_col3, #T_b80b4_row29_col3, #T_b80b4_row30_col3, #T_b80b4_row31_col3, #T_b80b4_row32_col3, #T_b80b4_row33_col3, #T_b80b4_row34_col3 {
#   background-color: #036e3a;
#   color: #f1f1f1;
# }
# #T_b80b4_row35_col3, #T_b80b4_row36_col3, #T_b80b4_row37_col3, #T_b80b4_row38_col3, #T_b80b4_row39_col3, #T_b80b4_row40_col3 {
#   background-color: #04703b;
#   color: #f1f1f1;
# }
# #T_b80b4_row41_col3, #T_b80b4_row42_col3, #T_b80b4_row43_col3, #T_b80b4_row44_col3, #T_b80b4_row45_col3, #T_b80b4_row46_col3, #T_b80b4_row47_col3, #T_b80b4_row48_col3, #T_b80b4_row49_col3, #T_b80b4_row50_col3, #T_b80b4_row51_col3, #T_b80b4_row52_col3, #T_b80b4_row53_col3, #T_b80b4_row54_col3, #T_b80b4_row55_col3, #T_b80b4_row56_col3 {
#   background-color: #05713c;
#   color: #f1f1f1;
# }
# #T_b80b4_row57_col3, #T_b80b4_row58_col3, #T_b80b4_row59_col3, #T_b80b4_row60_col3, #T_b80b4_row61_col3, #T_b80b4_row62_col3 {
#   background-color: #06733d;
#   color: #f1f1f1;
# }
# #T_b80b4_row63_col3, #T_b80b4_row64_col3, #T_b80b4_row65_col3, #T_b80b4_row66_col3, #T_b80b4_row67_col3, #T_b80b4_row68_col3, #T_b80b4_row69_col3, #T_b80b4_row70_col3, #T_b80b4_row71_col3, #T_b80b4_row72_col3, #T_b80b4_row73_col3, #T_b80b4_row74_col3, #T_b80b4_row75_col3, #T_b80b4_row76_col3, #T_b80b4_row77_col3, #T_b80b4_row78_col3 {
#   background-color: #07753e;
#   color: #f1f1f1;
# }
# #T_b80b4_row79_col3, #T_b80b4_row80_col3, #T_b80b4_row81_col3, #T_b80b4_row82_col3, #T_b80b4_row83_col3, #T_b80b4_row84_col3, #T_b80b4_row85_col3 {
#   background-color: #08773f;
#   color: #f1f1f1;
# }
# #T_b80b4_row86_col3, #T_b80b4_row87_col3, #T_b80b4_row88_col3, #T_b80b4_row89_col3, #T_b80b4_row90_col3, #T_b80b4_row91_col3, #T_b80b4_row92_col3, #T_b80b4_row93_col3, #T_b80b4_row94_col3, #T_b80b4_row95_col3, #T_b80b4_row96_col3, #T_b80b4_row97_col3, #T_b80b4_row98_col3, #T_b80b4_row99_col3, #T_b80b4_row100_col3 {
#   background-color: #097940;
#   color: #f1f1f1;
# }
# #T_b80b4_row101_col3, #T_b80b4_row102_col3, #T_b80b4_row103_col3, #T_b80b4_row104_col3, #T_b80b4_row105_col3, #T_b80b4_row106_col3, #T_b80b4_row107_col3, #T_b80b4_row108_col3, #T_b80b4_row109_col3, #T_b80b4_row110_col3 {
#   background-color: #0a7b41;
#   color: #f1f1f1;
# }
# #T_b80b4_row111_col3, #T_b80b4_row112_col3, #T_b80b4_row113_col3, #T_b80b4_row114_col3, #T_b80b4_row115_col3, #T_b80b4_row116_col3, #T_b80b4_row117_col3, #T_b80b4_row118_col3, #T_b80b4_row119_col3, #T_b80b4_row120_col3, #T_b80b4_row121_col3, #T_b80b4_row122_col3, #T_b80b4_row123_col3, #T_b80b4_row124_col3, #T_b80b4_row125_col3, #T_b80b4_row126_col3 {
#   background-color: #0b7d42;
#   color: #f1f1f1;
# }
# #T_b80b4_row127_col3, #T_b80b4_row128_col3, #T_b80b4_row129_col3, #T_b80b4_row130_col3, #T_b80b4_row131_col3, #T_b80b4_row132_col3, #T_b80b4_row133_col3, #T_b80b4_row134_col3, #T_b80b4_row135_col3, #T_b80b4_row136_col3, #T_b80b4_row137_col3 {
#   background-color: #0c7f43;
#   color: #f1f1f1;
# }
# #T_b80b4_row128_col7, #T_b80b4_row130_col7, #T_b80b4_row153_col7, #T_b80b4_row154_col7, #T_b80b4_row157_col7, #T_b80b4_row172_col7, #T_b80b4_row174_col7, #T_b80b4_row176_col7, #T_b80b4_row180_col7, #T_b80b4_row190_col7 {
#   background-color: #ffeee7;
#   color: #000000;
# }
# #T_b80b4_row138_col3, #T_b80b4_row139_col3, #T_b80b4_row140_col3, #T_b80b4_row141_col3, #T_b80b4_row142_col3, #T_b80b4_row143_col3, #T_b80b4_row144_col3, #T_b80b4_row145_col3, #T_b80b4_row146_col3, #T_b80b4_row147_col3, #T_b80b4_row148_col3, #T_b80b4_row149_col3, #T_b80b4_row150_col3, #T_b80b4_row151_col3, #T_b80b4_row152_col3

# %% [markdown]
# ## Stacked decomposition across all configs
#
# Each bar is one config sorted by step_ms. Components stacked: target forward → EAGLE3 draft → verify overhead → post verify. The dashed line marks vanilla step latency.

# %%
# Sort by step_total_ms (true per-step latency) not step_ms (TPOT in real spec mode)
order = ok.sort_values('step_total_ms').reset_index(drop=True)
labels = [f"k={r.topk} s={r.steps} B={r.budget}" for r in order.itertuples()]

comps = [
    ('target_forward_ms', '#4c72b0', 'target forward'),
    ('eagle3_draft_ms',   '#55a868', 'EAGLE3 draft'),
    ('verify_overhead_ms','#c44e52', 'verify overhead'),
    ('post_verify_ms',    '#8172b2', 'post verify'),
]

fig, ax = plt.subplots(figsize=(max(14, 0.15 * len(order)), 6))
bottom = np.zeros(len(order))
for col, color, label in comps:
    ax.bar(range(len(order)), order[col], bottom=bottom, color=color, label=label, width=0.9)
    bottom = bottom + order[col].values

ax.axhline(vanilla_tpot, ls='--', color='black', alpha=0.6, label=f'vanilla ({vanilla_tpot:.1f} ms)')
ax.set_xticks(range(len(order)))
ax.set_xticklabels(labels, rotation=90, fontsize=7)
ax.set_ylabel('ms per step')
ax.set_title('EAGLE3 per-step latency decomposition (sorted by step_ms)')
ax.legend(loc='upper left')
ax.margins(x=0.005)
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Budget sweep per (topk, steps)
#
# For each (topk, steps) combination with ≥2 successful budgets, plot step_ms and its components vs budget. Shows where verify overhead starts dominating.

# %%
pairs = [(t, s) for (t, s), g in ok.groupby(['topk', 'steps']) if len(g) >= 2]
pairs.sort()

ncols = 4
nrows = int(np.ceil(len(pairs) / ncols))
fig, axes = plt.subplots(nrows, ncols, figsize=(4.2 * ncols, 3.2 * nrows),
                         sharey=False, squeeze=False)

for ax, (tk, st) in zip(axes.flat, pairs):
    g = ok[(ok.topk == tk) & (ok.steps == st)].sort_values('budget')
    x = g['budget'].values
    # step_total_ms = true per-step latency (one draft + verify round)
    ax.plot(x, g['step_total_ms'], 'o-', color='black', lw=2,
            label='step total (per-step latency)')
    ax.plot(x, g['target_forward_ms'], 's--', color='#4c72b0', label='target fwd')
    ax.plot(x, g['eagle3_draft_ms'], 'd--', color='#55a868', label='draft')
    ax.plot(x, g['verify_overhead_ms'], 'v--', color='#c44e52', label='verify ovhd')
    ax.plot(x, g['post_verify_ms'], '^--', color='#8172b2', label='post verify')
    ax.axhline(vanilla_tpot, ls=':', color='gray', alpha=0.7)
    ax.set_title(f'topk={tk}, steps={st}')
    ax.set_xlabel('budget')
    ax.set_ylabel('ms')
    ax.set_xscale('log', base=2)
    if len(x) > 1 and x.max() > 0 and g['step_total_ms'].max() / g['step_total_ms'].min() > 3:
        ax.set_yscale('log')
    ax.grid(alpha=0.3)

for ax in axes.flat[len(pairs):]:
    ax.set_visible(False)

handles, labels = axes.flat[0].get_legend_handles_labels()
fig.legend(handles, labels, loc='lower center', ncol=5, bbox_to_anchor=(0.5, -0.02))
fig.suptitle('Per-step latency vs budget, faceted by (topk, steps)', y=1.0)
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Component isolation: how each knob affects each cost
#
# 1. **Draft cost** should scale with `steps` (draft model runs once per step).
# 2. **Target forward** should be nearly independent of all knobs (fixed by target model on fixed extend length).
# 3. **Verify overhead** should scale with `budget` (bigger tree → bigger mask → more work on GPU).

# %%
fig, axes = plt.subplots(1, 2)

# 1. draft vs steps, colored by topk (avg over budget)
ax = axes[0]
for tk, g in ok.groupby('topk'):
    agg = g.groupby('steps')['eagle3_draft_ms'].mean().reset_index()
    ax.plot(agg['steps'], agg['eagle3_draft_ms'], 'o-', label=f'topk={tk}')
ax.set_xlabel('steps')
ax.set_ylabel('eagle3_draft_ms (avg over budget)')
ax.set_title('Draft cost vs steps')
ax.legend()
ax.grid(alpha=0.3)

# 3. verify_overhead vs budget, separate line per (topk, steps)
ax = axes[1]
for (tk, st), g in ok.groupby(['topk', 'steps']):
    g = g.sort_values('budget')
    if len(g) >= 2:
        ax.plot(g['budget'], g['verify_overhead_ms'], 'o-', alpha=0.6, lw=1,
                label=f'k={tk} s={st}')
ax.set_xlabel('budget')
ax.set_ylabel('target_cost_ms')
ax.set_title('Target cost vs budget')
ax.set_xscale('log', base=2)
ax.set_yscale('log')
ax.grid(alpha=0.3, which='both')
# too many lines for a full legend — show only once outside
ax.legend(fontsize=6, ncol=2, loc='upper left')

plt.tight_layout()
plt.show()

# %% [markdown]
# ## Heatmaps: step_ms over (topk, steps) at fixed budgets
#
# One heatmap per budget value. Missing cells = error configs (budget exceeded SGLang `score_pool`).

# %%
budgets_to_show = [1, 4, 16, 64, 256, 1024]
budgets_to_show = [b for b in budgets_to_show if b in ok['budget'].unique()]

ncols = min(3, len(budgets_to_show))
nrows = int(np.ceil(len(budgets_to_show) / ncols))
fig, axes = plt.subplots(nrows, ncols, figsize=(4.8 * ncols, 3.6 * nrows), squeeze=False)

vmin = ok['step_total_ms'].min()
vmax = ok['step_total_ms'].max()

for ax, B in zip(axes.flat, budgets_to_show):
    sub = ok[ok['budget'] == B]
    pivot = sub.pivot(index='steps', columns='topk', values='step_total_ms')
    pivot = pivot.sort_index().sort_index(axis=1)
    im = ax.imshow(pivot.values, aspect='auto', cmap='RdYlGn_r',
                   norm=matplotlib.colors.LogNorm(vmin=vmin, vmax=vmax))
    ax.set_xticks(range(pivot.shape[1]))
    ax.set_xticklabels(pivot.columns)
    ax.set_yticks(range(pivot.shape[0]))
    ax.set_yticklabels(pivot.index)
    ax.set_xlabel('topk')
    ax.set_ylabel('steps')
    ax.set_title(f'step_total_ms @ budget={B}')
    for (i, j), v in np.ndenumerate(pivot.values):
        if not np.isnan(v):
            ax.text(j, i, f'{v:.0f}', ha='center', va='center',
                    color='white' if v > (vmin * vmax) ** 0.5 else 'black', fontsize=9)
    fig.colorbar(im, ax=ax, shrink=0.8)

for ax in axes.flat[len(budgets_to_show):]:
    ax.set_visible(False)

plt.tight_layout()
plt.show()

# %% [markdown]
# ## Failed configs (for reference)
#
# These hit `RuntimeError: selected index k out of range` in SGLang's `organize_draft_results`.
# The score pool size is `topk + (steps-1) * topk²`, and budget must satisfy `budget ≤ score_pool + 1`.

# %%
if len(err) > 0:
    err_view = err[['topk', 'steps', 'budget', 'max_capacity']].copy()
    err_view['score_pool'] = err_view['topk'] + (err_view['steps'] - 1) * err_view['topk'] ** 2
    err_view['budget_limit'] = err_view['score_pool'] + 1
    err_view['over_by'] = err_view['budget'] - err_view['budget_limit']
    print(f'{len(err_view)} failed configs:')
    print(err_view.to_string(index=False))
else:
    print('No failed configs.')
# Out:
# 46 failed configs:
#  topk  steps  budget  max_capacity  score_pool  budget_limit  over_by
#     2      4      16            30          14            15        1
#     2      5      32            62          18            19       13
#     2      6      32           126          22            23        9
#     2      6      64           126          22            23       41
#     2      7      32           254          26            27        5
#     2      7      64           254          26            27       37
#     2      7     128           254          26            27      101
#     2      8      32           510          30            31        1
#     2      8      64           510          30            31       33
#     2      8     128           510          30            31       97
#     2      8     256           510          30            31      225
#     4      3      64            84          36            37       27
#     4      4      64           340          52            53       11
#     4      4     128           340          52            53       75
#     4      4     256           340          52            53      203
#     4      5     128          1364          68            69       59
#     4      5     256          1364          68            69      187
#     4      5     512          1364          68            69      443
#     4      5    1024          1364          68            69      955
#     4      6     128          5460          84            85       43
#     4      6     256          5460          84            85      171
#     4      6     512          5460          84            85      427
#     4      6    1024          5460          84            85      939
#     4      7     128         21844         100           101       27
#     4      7     256         21844         100           101      155
#     4      7     512         21844         100           101      411
#     4      7    1024         21844         100           101      923
#     4      8     128         87380         116           117       11
#     4      8     256         87380         116           117      139
#     4      8     512         87380         116           117      395
#     4      8    1024         87380         116           117      907
#     8      3     256           584         136           137      119
#     8      3     512           584         136           137      375
#     8      4     256          4680         200           201       55
#     8      4     512          4680         200           201      311
#     8      4    1024          4680         200           201      823
#     8      5     512         37448         264           265      247
#     8      5    1024         37448         264           265      759
#     8      6     512        299592         328           329      183
#     8      6    1024        299592         328           329      695
#     8      7     512       2396744         392           393      119
#     8      7    1024       2396744         392           393      631
#     8      8     512      19173960         456           457       55
#     8      8    1024      19173960         456           457      567
#    16      3    1024          4368         528           529      495
#    16      4    1024         69904         784           785      239

# %% [markdown]
# ## Budget (num_draft_tokens) sweep — fixed topk=8, steps=5
#
# **target cost** = `target_forward_ms + verify_overhead_ms` (real target GPU wall time; coarse `target_forward_ms` alone undercounts async GPU completion).
# **draft cost** = EAGLE3 draft forward.
#
# Budget shown as actual numbers (log-spaced ticks).

# %%
import matplotlib.ticker as mtick

# True target cost = target_forward_ms + verify_overhead_ms
# (oracle_patch's target_forward_ms misses async GPU completion; the missing time
#  leaks into verify_overhead. Sum of both = real target forward wall time.)
# others = step_total - target_cost - draft (post_verify + misc)
ok_adj = ok.assign(
    target_cost_ms=ok["target_forward_ms"] + ok["verify_overhead_ms"],
    others_ms=ok["step_total_ms"]
        - (ok["target_forward_ms"] + ok["verify_overhead_ms"])
        - ok["eagle3_draft_ms"],
)

fix_topk, fix_steps =  16, 5
sub = ok_adj[(ok_adj.topk == fix_topk) & (ok_adj.steps == fix_steps)].sort_values("budget")

fig, ax = plt.subplots(figsize=(8, 5))
ax.plot(sub["budget"], sub["step_total_ms"], "o-", color="black",
        lw=2, label="total cost")
ax.plot(sub["budget"], sub["target_cost_ms"], "o-", color="#0072B2",
        lw=2, label="target cost")
ax.plot(sub["budget"], sub["eagle3_draft_ms"], "s-", color="#E69F00",
        lw=2, label="draft cost (EAGLE-3)")
ax.plot(sub["budget"], sub["others_ms"], "^-", color="#CC79A7",
        lw=2, label="others")
ax.set_xscale("log", base=2)
ax.xaxis.set_major_formatter(mtick.ScalarFormatter())
ax.xaxis.set_major_locator(mtick.FixedLocator(list(sub["budget"])))
ax.set_xlim(right=1300)
ax.set_ylim(top=200)
ax.set_xlabel("budget (num_draft_tokens)")
ax.set_ylabel("ms per step")
ax.set_title(f"Budget sweep (topk={fix_topk}, steps={fix_steps})")
ax.legend()
ax.grid(alpha=0.3)
plt.tight_layout()
plt.show()
sub[["budget", "step_total_ms", "target_cost_ms", "eagle3_draft_ms", "others_ms"]].to_string(index=False)

# %%
# Stacked bar view of the same budget sweep: target + draft + others = step_total
fix_topk, fix_steps = 16, 5
sub = ok_adj[(ok_adj.topk == fix_topk) & (ok_adj.steps == fix_steps)].sort_values("budget")

fig, ax = plt.subplots(figsize=(8, 5))
x = np.arange(len(sub))
ax.bar(x, sub["target_cost_ms"], color="#0072B2", label="target cost")
ax.bar(x, sub["eagle3_draft_ms"], bottom=sub["target_cost_ms"],
       color="#E69F00", label="draft cost (EAGLE-3)")
ax.bar(x, sub["others_ms"],
       bottom=sub["target_cost_ms"].values + sub["eagle3_draft_ms"].values,
       color="#CC79A7", label="others")
ax.set_xticks(x)
ax.set_xticklabels([str(b) for b in sub["budget"]])
ax.set_xlabel("budget (num_draft_tokens)")
ax.set_ylabel("ms per step")
ax.set_title(f"Budget sweep stacked (topk={fix_topk}, steps={fix_steps})")
ax.legend()
ax.grid(alpha=0.3, axis="y")
plt.tight_layout()
plt.show()

# %%
# MAT and speedup vs budget (same fixed topk/steps as above)
fix_topk, fix_steps = 16, 5  # keep in sync with the target/draft cost cell above
sub = ok[(ok.topk == fix_topk) & (ok.steps == fix_steps)].sort_values("budget")
speedup = vanilla_tpot / sub["step_ms"]

fig, axes = plt.subplots(1, 2, figsize=(13, 4.5))

ax = axes[0]
ax.plot(sub["budget"], sub["committed_tokens_mean"], "o-",
        color="#d62728", lw=2, label="MAT (committed tokens / step)")
ax.plot(sub["budget"], sub["accept_length_mean"], "s--",
        color="#ff7f0e", lw=1.5, alpha=0.7, label="accept_length (excl. bonus)")
ax.axhline(1.0, ls=":", color="gray", alpha=0.5)
ax.set_xscale("log", base=2)
ax.xaxis.set_major_formatter(mtick.ScalarFormatter())
ax.xaxis.set_major_locator(mtick.FixedLocator(list(sub["budget"])))
ax.set_xlabel("budget (num_draft_tokens)")
ax.set_ylabel("tokens per step")
ax.set_title(f"MAT vs budget (topk={fix_topk}, steps={fix_steps})")
ax.legend()
ax.grid(alpha=0.3)

ax = axes[1]
ax.plot(sub["budget"], speedup, "o-", color="#2ca02c", lw=2)
ax.axhline(1.0, ls="--", color="gray", alpha=0.5, label="no speedup")
ax.set_xscale("log", base=2)
ax.xaxis.set_major_formatter(mtick.ScalarFormatter())
ax.xaxis.set_major_locator(mtick.FixedLocator(list(sub["budget"])))
ax.set_xlabel("budget (num_draft_tokens)")
ax.set_ylabel("speedup (vanilla TPOT / measured TPOT)")
ax.set_title(f"Speedup vs budget (topk={fix_topk}, steps={fix_steps})")
ax.legend()
ax.grid(alpha=0.3)

plt.tight_layout()
plt.show()
sub[["budget", "committed_tokens_mean", "accept_length_mean",
     "step_ms", "step_total_ms"]].to_string(index=False)
# Out:
# ' budget  committed_tokens_mean  accept_length_mean  step_ms  step_total_ms\n      1                  1.000               0.000    32.52          32.30\n      2                  1.493               0.493    22.40          33.17\n      4                  1.815               0.815    18.42          33.29\n      8                  2.054               1.054    16.30          33.40\n     16                  2.268               1.268    14.97          33.89\n     32                  2.553               1.553    15.10          38.31\n     64                  2.681               1.681    15.68          42.54\n    128                  2.882               1.882    15.84          45.36\n    256                  3.053               2.053    18.19          55.54\n    512                  3.140               2.140    30.40          94.30\n   1024                  3.178               2.178    55.86         177.31'

# %% [markdown]
# ## Branch (topk) sweep — fixed budget=64, steps=5
#
# Same `target cost` / `draft cost` definitions as above.

# %%
fix_budget, fix_steps = 64, 5
sub = ok_adj[(ok_adj.budget == fix_budget) & (ok_adj.steps == fix_steps)].sort_values("topk")

fig, ax = plt.subplots(figsize=(8, 5))
ax.plot(sub["topk"], sub["step_total_ms"], "o-", color="black",
        lw=2, label="total cost")
ax.plot(sub["topk"], sub["target_cost_ms"], "o-", color="#0072B2",
        lw=2, label="target cost")
ax.plot(sub["topk"], sub["eagle3_draft_ms"], "s-", color="#E69F00",
        lw=2, label="draft cost (EAGLE-3)")
ax.plot(sub["topk"], sub["others_ms"], "^-", color="#CC79A7",
        lw=2, label="others")
ax.set_xscale("log", base=2)
ax.xaxis.set_major_formatter(mtick.ScalarFormatter())
ax.xaxis.set_major_locator(mtick.FixedLocator(list(sub["topk"])))
ax.set_xlabel("branch (topk)")
ax.set_ylabel("ms per step")
ax.set_title(f"Branch sweep (budget={fix_budget}, steps={fix_steps})")
ax.legend()
ax.grid(alpha=0.3)
plt.tight_layout()
plt.show()
sub[["topk", "step_total_ms", "target_cost_ms", "eagle3_draft_ms", "others_ms"]].to_string(index=False)

# %%
# Stacked bar view of the same branch sweep
fix_budget, fix_steps = 64, 5
sub = ok_adj[(ok_adj.budget == fix_budget) & (ok_adj.steps == fix_steps)].sort_values("topk")

fig, ax = plt.subplots(figsize=(8, 5))
x = np.arange(len(sub))
ax.bar(x, sub["target_cost_ms"], color="#0072B2", label="target cost")
ax.bar(x, sub["eagle3_draft_ms"], bottom=sub["target_cost_ms"],
       color="#E69F00", label="draft cost (EAGLE-3)")
ax.bar(x, sub["others_ms"],
       bottom=sub["target_cost_ms"].values + sub["eagle3_draft_ms"].values,
       color="#CC79A7", label="others")
ax.set_xticks(x)
ax.set_xticklabels([str(t) for t in sub["topk"]])
ax.set_xlabel("branch (topk)")
ax.set_ylabel("ms per step")
ax.set_title(f"Branch sweep stacked (budget={fix_budget}, steps={fix_steps})")
ax.legend()
ax.grid(alpha=0.3, axis="y")
plt.tight_layout()
plt.show()

# %%
# MAT and speedup vs branch (same fixed budget/steps as above)
fix_budget, fix_steps = 64, 5
sub = ok[(ok.budget == fix_budget) & (ok.steps == fix_steps)].sort_values("topk")
speedup = vanilla_tpot / sub["step_ms"]

fig, axes = plt.subplots(1, 2, figsize=(13, 4.5))

ax = axes[0]
ax.plot(sub["topk"], sub["committed_tokens_mean"], "o-",
        color="#d62728", lw=2, label="MAT (committed tokens / step)")
ax.plot(sub["topk"], sub["accept_length_mean"], "s--",
        color="#ff7f0e", lw=1.5, alpha=0.7, label="accept_length (excl. bonus)")
ax.axhline(1.0, ls=":", color="gray", alpha=0.5)
ax.set_xscale("log", base=2)
ax.xaxis.set_major_formatter(mtick.ScalarFormatter())
ax.xaxis.set_major_locator(mtick.FixedLocator(list(sub["topk"])))
ax.set_xlabel("branch (topk)")
ax.set_ylabel("tokens per step")
ax.set_title(f"MAT vs branch (budget={fix_budget}, steps={fix_steps})")
ax.legend()
ax.grid(alpha=0.3)

ax = axes[1]
ax.plot(sub["topk"], speedup, "o-", color="#2ca02c", lw=2)
ax.axhline(1.0, ls="--", color="gray", alpha=0.5, label="no speedup")
ax.set_xscale("log", base=2)
ax.xaxis.set_major_formatter(mtick.ScalarFormatter())
ax.xaxis.set_major_locator(mtick.FixedLocator(list(sub["topk"])))
ax.set_xlabel("branch (topk)")
ax.set_ylabel("speedup (vanilla TPOT / measured TPOT)")
ax.set_title(f"Speedup vs branch (budget={fix_budget}, steps={fix_steps})")
ax.legend()
ax.grid(alpha=0.3)

plt.tight_layout()
plt.show()
sub[["topk", "committed_tokens_mean", "accept_length_mean",
     "step_ms", "step_total_ms"]].to_string(index=False)
# Out:
# ' topk  committed_tokens_mean  accept_length_mean  step_ms  step_total_ms\n    4                  2.529               1.529    16.88          42.24\n    8                  2.719               1.719    15.60          42.31\n   16                  2.681               1.681    15.68          42.54'

# %% [markdown]
# ## Depth (steps) sweep — fixed budget=256, topk=16
#
# Same `target cost` / `draft cost` definitions.

# %%
fix_budget, fix_topk = 256, 16
sub = ok_adj[(ok_adj.budget == fix_budget) & (ok_adj.topk == fix_topk)].sort_values("steps")

fig, ax = plt.subplots(figsize=(8, 5))
ax.plot(sub["steps"], sub["step_total_ms"], "o-", color="black",
        lw=2, label="total cost")
ax.plot(sub["steps"], sub["target_cost_ms"], "o-", color="#0072B2",
        lw=2, label="target cost")
ax.plot(sub["steps"], sub["eagle3_draft_ms"], "s-", color="#E69F00",
        lw=2, label="draft cost (EAGLE-3)")
ax.plot(sub["steps"], sub["others_ms"], "^-", color="#CC79A7",
        lw=2, label="others")
ax.set_xlabel("depth (steps)")
ax.set_ylabel("ms per step")
ax.set_title(f"Depth sweep (budget={fix_budget}, topk={fix_topk})")
ax.set_xticks(list(sub["steps"]))
ax.legend()
ax.grid(alpha=0.3)
plt.tight_layout()
plt.show()
sub[["steps", "step_total_ms", "target_cost_ms", "eagle3_draft_ms", "others_ms"]].to_string(index=False)

# %%
# Stacked bar view of the same depth sweep
fix_budget, fix_topk = 256, 16
sub = ok_adj[(ok_adj.budget == fix_budget) & (ok_adj.topk == fix_topk)].sort_values("steps")

fig, ax = plt.subplots(figsize=(8, 5))
x = np.arange(len(sub))
ax.bar(x, sub["target_cost_ms"], color="#0072B2", label="target cost")
ax.bar(x, sub["eagle3_draft_ms"], bottom=sub["target_cost_ms"],
       color="#E69F00", label="draft cost (EAGLE-3)")
ax.bar(x, sub["others_ms"],
       bottom=sub["target_cost_ms"].values + sub["eagle3_draft_ms"].values,
       color="#CC79A7", label="others")
ax.set_xticks(x)
ax.set_xticklabels([str(s) for s in sub["steps"]])
ax.set_xlabel("depth (steps)")
ax.set_ylabel("ms per step")
ax.set_title(f"Depth sweep stacked (budget={fix_budget}, topk={fix_topk})")
ax.legend()
ax.grid(alpha=0.3, axis="y")
plt.tight_layout()
plt.show()

# %%
# MAT and speedup vs depth (same fixed budget/topk as above)
fix_budget, fix_topk = 256, 16
sub = ok[(ok.budget == fix_budget) & (ok.topk == fix_topk)].sort_values("steps")
speedup = vanilla_tpot / sub["step_ms"]

fig, axes = plt.subplots(1, 2, figsize=(13, 4.5))

ax = axes[0]
ax.plot(sub["steps"], sub["committed_tokens_mean"], "o-",
        color="#d62728", lw=2, label="MAT (committed tokens / step)")
ax.plot(sub["steps"], sub["accept_length_mean"], "s--",
        color="#ff7f0e", lw=1.5, alpha=0.7, label="accept_length (excl. bonus)")
ax.axhline(1.0, ls=":", color="gray", alpha=0.5)
ax.set_xlabel("depth (steps)")
ax.set_ylabel("tokens per step")
ax.set_title(f"MAT vs depth (budget={fix_budget}, topk={fix_topk})")
ax.set_xticks(list(sub["steps"]))
ax.legend()
ax.grid(alpha=0.3)

ax = axes[1]
ax.plot(sub["steps"], speedup, "o-", color="#2ca02c", lw=2)
ax.axhline(1.0, ls="--", color="gray", alpha=0.5, label="no speedup")
ax.set_xlabel("depth (steps)")
ax.set_ylabel("speedup (vanilla TPOT / measured TPOT)")
ax.set_title(f"Speedup vs depth (budget={fix_budget}, topk={fix_topk})")
ax.set_xticks(list(sub["steps"]))
ax.legend()
ax.grid(alpha=0.3)

plt.tight_layout()
plt.show()
sub[["steps", "committed_tokens_mean", "accept_length_mean",
     "step_ms", "step_total_ms"]].to_string(index=False)
# Out:
# ' steps  committed_tokens_mean  accept_length_mean  step_ms  step_total_ms\n     2                  2.654               1.654    19.65          51.93\n     3                  3.015               2.015    17.70          53.18\n     4                  3.113               2.113    17.56          54.40\n     5                  3.053               2.053    18.19          55.54\n     6                  3.052               2.052    18.58          56.71\n     7                  3.096               2.096    18.67          57.96\n     8                  3.052               2.052    19.32          59.06'

# %% [markdown]
# ## Draft tree visualization
#
# Load the first draft record from `trees/topk{T}_steps{S}_budget{B}.jsonl` and render the tree.
# Prefers graphviz (via `pydot`); falls back to networkx hierarchical layout if graphviz is unavailable.
#
# Nodes labelled with token id + decoded text. No per-node score displayed.

# %%
# Config to visualize
TREE_TOPK, TREE_STEPS, TREE_BUDGET = 8, 5, 64
TREE_STEP_INDEX = 49   # 0=first draft step, 49=50th
TREE_PREV_CONTEXT = 2  # how many prior tokens to include before ROOT
TREE_DIR = Path(BENCH_PATH).resolve().parent / "trees"
TREE_PATH = TREE_DIR / f"topk{TREE_TOPK}_steps{TREE_STEPS}_budget{TREE_BUDGET}.jsonl"

# Load the N-th draft record + previous context records
ctx_start = max(0, TREE_STEP_INDEX - TREE_PREV_CONTEXT)
records = []
with open(TREE_PATH) as f:
    for idx, line in enumerate(f):
        if idx < ctx_start:
            continue
        if idx > TREE_STEP_INDEX:
            break
        records.append(json.loads(line))
if not records:
    raise IndexError(f"Tree log has fewer than {TREE_STEP_INDEX + 1} records")

rec = records[-1]
tree = rec["eagle3_tree"]
token_ids = tree["token_ids"]
parents = tree["parents"]

# Root token: position 0 of candidates (= verified bonus from previous step)
root_token = rec["eagle3"][0][0]
# This step's accepted bonus (target argmax at root position). With oracle patch
# this is the only token actually committed; it will become next step's ROOT.
bonus_token = rec["tokens"][0][0]
# Prev context: root tokens of preceding steps (chain of verified tokens)
prev_tokens = [r["eagle3"][0][0] for r in records[:-1]]

# Accepted draft node indices = direct children of ROOT whose token_id matches
# the bonus target predicted at root position. These are what would have been
# accepted in normal (non-oracle) EAGLE3 verification at depth 1.
accepted_idx = [i for i, (tid, p) in enumerate(zip(token_ids, parents))
                if p == -1 and tid == bonus_token]

print(f"Tree: {len(token_ids)} draft nodes, step_index={TREE_STEP_INDEX}, "
      f"req_id={rec['req_id'][:16]}...")
print(f"ROOT token id: {root_token}   (verified from previous step)")
print(f"Bonus token id: {bonus_token} (target predicted, would be next ROOT)")
print(f"Would-be-accepted root children matching bonus: {accepted_idx}")
print(f"Prev {len(prev_tokens)} root tokens: {prev_tokens}")

# Decode tokens for readable labels
try:
    from transformers import AutoTokenizer
    tok = AutoTokenizer.from_pretrained(data["model"], trust_remote_code=True)
    decoded = [tok.decode([tid]) for tid in token_ids]
    root_decoded = tok.decode([root_token])
    bonus_decoded = tok.decode([bonus_token])
    prev_decoded = [tok.decode([t]) for t in prev_tokens]
    print(f"ROOT: {root_decoded!r}  |  BONUS: {bonus_decoded!r}")
    print(f"Prev decoded: {prev_decoded!r}")
except Exception as e:
    print(f"(tokenizer load failed: {e}; showing token ids only)")
    decoded = [""] * len(token_ids)
    root_decoded = ""; bonus_decoded = ""
    prev_decoded = [""] * len(prev_tokens)

def node_label(i):
    txt = decoded[i].replace("\n", "\\n").replace('"', '\\"').strip()
    return f"{token_ids[i]}\n{txt!r}" if txt else f"{token_ids[i]}"

def ctx_label(tid, txt):
    t = txt.replace("\n", "\\n").replace('"', '\\"').strip()
    return f"{tid}\n{t!r}" if t else f"{tid}"
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[99], line 11
#       7
#       8 # Load the N-th draft record + previous context records
#       9 ctx_start = max(0, TREE_STEP_INDEX - TREE_PREV_CONTEXT)
#      10 records = []
# ---> 11 with open(TREE_PATH) as f:
#      12     for idx, line in enumerate(f):
#      13         if idx < ctx_start:
#      14             continue
#
# FileNotFoundError: [Errno 2] No such file or directory: '/home/muchwater/advance-spec/results/qwen3_14b/trees/topk8_steps5_budget64.jsonl'

# %%
# Output location for saved tree images
TREE_OUT_DIR = Path(BENCH_PATH).parent.parent.parent / "tree_plots"
TREE_OUT_DIR.mkdir(parents=True, exist_ok=True)
base = f"tree_topk{TREE_TOPK}_steps{TREE_STEPS}_budget{TREE_BUDGET}_step{TREE_STEP_INDEX}"

# Color scheme
CTX_COLOR   = "#fff2cc"  # yellow-ish: previous-context tokens
ROOT_COLOR  = "#ffd6a5"  # orange: verified ROOT (previously accepted)
DRAFT_COLOR = "#cfe4ff"  # blue: unaccepted draft
ACCEPT_COLOR= "#b7f7c1"  # green: draft node matching bonus (would-be-accepted)
BONUS_COLOR = "#4caf50"  # darker green: the bonus token itself (target-predicted next)

rendered = False
try:
    import pydot
    g = pydot.Dot(graph_type="digraph", rankdir="TB", nodesep="0.3", ranksep="0.6")

    # Context chain: ctx0 -> ctx1 -> ... -> ROOT
    prev_node_ids = []
    for k, (tid, txt) in enumerate(zip(prev_tokens, prev_decoded)):
        nid = f"ctx{k}"
        g.add_node(pydot.Node(nid, label=ctx_label(tid, txt),
                              shape="ellipse", style="filled",
                              fillcolor=CTX_COLOR, fontsize="9"))
        prev_node_ids.append(nid)

    # ROOT (verified, highlighted)
    g.add_node(pydot.Node("root",
                          label=f"ROOT (accepted)\n{ctx_label(root_token, root_decoded)}",
                          shape="ellipse", style="filled,bold",
                          fillcolor=ROOT_COLOR, fontsize="10"))
    for prev_nid, next_nid in zip(prev_node_ids, prev_node_ids[1:] + ["root"]):
        g.add_edge(pydot.Edge(prev_nid, next_nid, style="dashed", color="#888888"))

    # Draft tree nodes — recolor accepted ones
    accepted_set = set(accepted_idx)
    for i, tid in enumerate(token_ids):
        color = ACCEPT_COLOR if i in accepted_set else DRAFT_COLOR
        style = "rounded,filled,bold" if i in accepted_set else "rounded,filled"
        g.add_node(pydot.Node(str(i), label=node_label(i),
                              shape="box", style=style,
                              fillcolor=color, fontsize="9"))
    for i, p in enumerate(parents):
        src = "root" if p == -1 else str(p)
        g.add_edge(pydot.Edge(src, str(i)))

    # Add the BONUS token node after ROOT (shown separately to indicate what
    # target actually committed this step — becomes next step's ROOT)
    g.add_node(pydot.Node("bonus",
                          label=f"BONUS\n{ctx_label(bonus_token, bonus_decoded)}",
                          shape="ellipse", style="filled,bold",
                          fillcolor=BONUS_COLOR, fontcolor="white", fontsize="10"))
    g.add_edge(pydot.Edge("root", "bonus", color="#1b5e20", penwidth="2"))

    png_path = TREE_OUT_DIR / f"{base}.png"
    svg_path = TREE_OUT_DIR / f"{base}.svg"
    dot_path = TREE_OUT_DIR / f"{base}.dot"
    g.write_png(str(png_path))
    g.write_svg(str(svg_path))
    g.write_raw(str(dot_path))

    from IPython.display import Image, display
    display(Image(str(png_path)))
    print(f"Rendered {len(token_ids)} draft + {len(prev_tokens)} ctx + ROOT + BONUS via graphviz")
    print(f"  accepted (green) node indices: {accepted_idx}")
    print(f"  saved: {png_path.name}, {svg_path.name}, {dot_path.name}")
    print(f"  dir:   {TREE_OUT_DIR}")
    rendered = True
except Exception as e:
    print(f"graphviz path failed: {e!r}")
    print("Falling back to networkx...")

if not rendered:
    import networkx as nx
    G = nx.DiGraph()
    prev_node_ids = []
    for k, (tid, txt) in enumerate(zip(prev_tokens, prev_decoded)):
        nid = f"ctx{k}"
        G.add_node(nid, kind="ctx")
        prev_node_ids.append(nid)
    G.add_node("root", kind="root")
    G.add_node("bonus", kind="bonus")
    for prev_nid, next_nid in zip(prev_node_ids, prev_node_ids[1:] + ["root"]):
        G.add_edge(prev_nid, next_nid)
    G.add_edge("root", "bonus")
    accepted_set = set(accepted_idx)
    for i in range(len(token_ids)):
        G.add_node(i, kind="accept" if i in accepted_set else "draft")
    for i, p in enumerate(parents):
        G.add_edge("root" if p == -1 else p, i)

    levels = {}
    for k, nid in enumerate(prev_node_ids):
        levels[nid] = k
    levels["root"] = len(prev_node_ids)
    for i, p in enumerate(parents):
        parent = "root" if p == -1 else p
        levels[i] = levels.get(parent, len(prev_node_ids)) + 1
    levels["bonus"] = max(levels.values()) + 1
    max_level = max(levels.values())
    by_level = {}
    for n, lv in levels.items():
        by_level.setdefault(lv, []).append(n)
    pos = {}
    for lv, nodes in by_level.items():
        for j, n in enumerate(nodes):
            x = (j + 1) / (len(nodes) + 1)
            pos[n] = (x, -lv)
    color_map = {"ctx": CTX_COLOR, "root": ROOT_COLOR, "draft": DRAFT_COLOR,
                 "accept": ACCEPT_COLOR, "bonus": BONUS_COLOR}
    node_colors = [color_map[G.nodes[n]["kind"]] for n in G.nodes]

    fig, ax = plt.subplots(figsize=(max(10, len(by_level.get(len(prev_node_ids) + 1, [])) * 2),
                                     2.2 * (max_level + 1)))
    nx.draw(G, pos, node_color=node_colors, with_labels=False,
            node_size=700, arrows=True, arrowsize=8, ax=ax, width=0.6)
    for n, (x, y) in pos.items():
        if n in prev_node_ids:
            idx = int(n[3:]); lbl = ctx_label(prev_tokens[idx], prev_decoded[idx])
        elif n == "root":
            lbl = f"ROOT\n{ctx_label(root_token, root_decoded)}"
        elif n == "bonus":
            lbl = f"BONUS\n{ctx_label(bonus_token, bonus_decoded)}"
        else:
            lbl = node_label(n)
        ax.text(x, y - 0.15, lbl, ha="center", va="top", fontsize=7)
    ax.set_title(f"Draft tree + ctx (topk={TREE_TOPK}, steps={TREE_STEPS}, "
                 f"budget={TREE_BUDGET}, step={TREE_STEP_INDEX})")
    ax.set_axis_off()
    plt.tight_layout()
    png_path = TREE_OUT_DIR / f"{base}.png"
    pdf_path = TREE_OUT_DIR / f"{base}.pdf"
    fig.savefig(png_path, dpi=200, bbox_inches="tight")
    fig.savefig(pdf_path, bbox_inches="tight")
    plt.show()
    print(f"Rendered {len(token_ids)} draft + ctx + ROOT + BONUS via networkx")
    print(f"  accepted node indices: {accepted_idx}")
    print(f"  saved: {png_path.name}, {pdf_path.name}")
